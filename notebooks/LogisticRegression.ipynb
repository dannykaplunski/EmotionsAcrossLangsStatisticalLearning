# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import average_precision_score, make_scorer
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_curve, roc_auc_score
import matplotlib.pyplot as plt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from matplotlib.patches import Patch
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %% [markdown]
# # Part 1: Without Clustering Data

# %%
#get the data sets
X_train = pd.read_csv('../data/train_df.csv')
X_test = pd.read_csv('../data/test_df.csv')
y_train = pd.read_csv('../data/y_train.csv')
y_test = pd.read_csv('../data/y_test.csv')

# %% [markdown]
# Logistic Regression

# %%
#set up scoring function
scorer = make_scorer(average_precision_score, needs_proba=True)

# Define the model
model = LogisticRegression(penalty='l1', random_state=42)

# Define the parameter grid
param_grid = {
    'C': [0.01, 0.1, 1, 10, 100],
    'solver': ['liblinear', 'saga']
}

#Find the estimators
grid_search = GridSearchCV(model, param_grid, cv=5, scoring=scorer, verbose=5)
# Out:
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/metrics/_scorer.py:548: FutureWarning: The `needs_threshold` and `needs_proba` parameter are deprecated in version 1.4 and will be removed in 1.6. You can either let `response_method` be `None` or set it to `predict` to preserve the same behaviour.
#   warnings.warn(

# %%
grid_search.fit(X_train, y_train)
# Out:
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..........C=0.01, solver=liblinear;, score=0.933 total time=   0.1s
# [CV 2/5] END ..........C=0.01, solver=liblinear;, score=0.929 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ..........C=0.01, solver=liblinear;, score=0.941 total time=   0.2s
# [CV 4/5] END ..........C=0.01, solver=liblinear;, score=0.930 total time=   0.1s
# [CV 5/5] END ..........C=0.01, solver=liblinear;, score=0.921 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ...............C=0.01, solver=saga;, score=0.928 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ...............C=0.01, solver=saga;, score=0.926 total time=   0.7s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ...............C=0.01, solver=saga;, score=0.936 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...............C=0.01, solver=saga;, score=0.928 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ...............C=0.01, solver=saga;, score=0.916 total time=   0.7s
# [CV 1/5] END ...........C=0.1, solver=liblinear;, score=0.966 total time=   0.1s
# [CV 2/5] END ...........C=0.1, solver=liblinear;, score=0.976 total time=   0.1s
# [CV 3/5] END ...........C=0.1, solver=liblinear;, score=0.977 total time=   0.2s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...........C=0.1, solver=liblinear;, score=0.966 total time=   0.1s
# [CV 5/5] END ...........C=0.1, solver=liblinear;, score=0.957 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ................C=0.1, solver=saga;, score=0.961 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ................C=0.1, solver=saga;, score=0.969 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ................C=0.1, solver=saga;, score=0.974 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ................C=0.1, solver=saga;, score=0.958 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ................C=0.1, solver=saga;, score=0.950 total time=   1.0s
# [CV 1/5] END .............C=1, solver=liblinear;, score=0.941 total time=   0.7s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .............C=1, solver=liblinear;, score=0.964 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .............C=1, solver=liblinear;, score=0.955 total time=   0.7s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END .............C=1, solver=liblinear;, score=0.923 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END .............C=1, solver=liblinear;, score=0.936 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ..................C=1, solver=saga;, score=0.925 total time=   1.0s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ..................C=1, solver=saga;, score=0.964 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ..................C=1, solver=saga;, score=0.969 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ..................C=1, solver=saga;, score=0.950 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ..................C=1, solver=saga;, score=0.945 total time=   1.2s
# [CV 1/5] END ............C=10, solver=liblinear;, score=0.886 total time=   1.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ............C=10, solver=liblinear;, score=0.925 total time=   1.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ............C=10, solver=liblinear;, score=0.925 total time=   2.2s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ............C=10, solver=liblinear;, score=0.909 total time=   1.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ............C=10, solver=liblinear;, score=0.923 total time=   1.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END .................C=10, solver=saga;, score=0.922 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .................C=10, solver=saga;, score=0.963 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .................C=10, solver=saga;, score=0.967 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END .................C=10, solver=saga;, score=0.943 total time=   1.0s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END .................C=10, solver=saga;, score=0.942 total time=   0.9s
# [CV 1/5] END ...........C=100, solver=liblinear;, score=0.883 total time=   1.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ...........C=100, solver=liblinear;, score=0.910 total time=   1.5s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ...........C=100, solver=liblinear;, score=0.922 total time=   1.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...........C=100, solver=liblinear;, score=0.904 total time=   1.4s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ...........C=100, solver=liblinear;, score=0.908 total time=   1.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ................C=100, solver=saga;, score=0.921 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ................C=100, solver=saga;, score=0.962 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ................C=100, solver=saga;, score=0.967 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ................C=100, solver=saga;, score=0.942 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ................C=100, solver=saga;, score=0.942 total time=   0.9s
# GridSearchCV(cv=5, estimator=LogisticRegression(penalty='l1', random_state=42),
#              param_grid={'C': [0.01, 0.1, 1, 10, 100],
#                          'solver': ['liblinear', 'saga']},
#              scoring=make_scorer(average_precision_score, response_method='predict_proba'),
#              verbose=5)

# %%
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
# Out:
# Best parameters: {'C': 0.1, 'solver': 'liblinear'}
# Best cross-validation score: 0.97

# %%
best_model = grid_search.best_estimator_

# %%
# Predict test data
y_pred = best_model.predict(X_test)

# Evaluate the model
print("Test Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred))
# Out:
# Test Accuracy: 0.9397590361445783
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       169
#            1       0.93      0.88      0.90        80
#
#     accuracy                           0.94       249
#    macro avg       0.94      0.92      0.93       249
# weighted avg       0.94      0.94      0.94       249
#
# Confusion Matrix:
#  [[164   5]
#  [ 10  70]]

# %%
y_pred_prob = best_model.predict_proba(X_test)

# %%
#Make ROC Curve
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob[:, 1])

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, label=f'ROC curve (area = {roc_auc_score(y_test, y_pred_prob[:, 1]):.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')
plt.show()

# %%
#Find features with non-0 betas

#get full list of features and their coefficients
features = X_test.columns
coefficients = best_model.coef_.flatten()
fulllist= pd.DataFrame(np.transpose([features, coefficients]))
#remove rows with 0 as a coefficient
shortlist = fulllist[fulllist[1] != 0]
#show how many features were not kicked out of the model:
print(len(shortlist))
# Out:
# 105

# %%
#sort and plot the coefficients
coef_sorted = shortlist.reindex(shortlist[1].abs().sort_values(ascending=False).index)
coef_sorted['Abs_Coef'] = coef_sorted[1].abs()
coef_sorted
# Out:
#                                0         1  Abs_Coef
# 622                 language_EST -1.590223  1.590223
# 22                  mfccs_mean_2  1.281543  1.281543
# 20                  mfccs_mean_0 -0.965072  0.965072
# 23                  mfccs_mean_3  0.819667  0.819667
# 126                       magmax   0.69448   0.69448
# ..                           ...       ...       ...
# 59               zcr_frequncys_3 -0.000027  0.000027
# 95   zcr_frequncys_from_average0  0.000021  0.000021
# 57               zcr_frequncys_1 -0.000021  0.000021
# 93                 frequncys_zcr -0.000015  0.000015
# 56               zcr_frequncys_0 -0.000008  0.000008
#
# [105 rows x 3 columns]

# %%
#look at all of them to get their distribution
colors = ['blue' if val >= 0 else 'orange' for val in coef_sorted[1]]
plt.bar(range(len(coef_sorted[0])), coef_sorted['Abs_Coef'], color=colors)
#plt.bar(coef_sorted[0], coef_sorted['Abs_Coef'], color=colors)
plt.xlabel('# Features')
plt.ylabel('Magnitude of Coefficient')
plt.title('Coefficients for All Features')

legend_labels = [Patch(color='blue', label='+ Correlation'),
                 Patch(color='orange', label='- Correlation')]
plt.legend(handles=legend_labels)

plt.show()

# %%
#look at just the top few of them to get their distribution
numtop = 18
#reverses the order
coef_sorted = coef_sorted.iloc[::-1]

colors = ['blue' if val >= 0 else 'orange' for val in coef_sorted[1]]
plt.barh(coef_sorted[0][-numtop:], coef_sorted['Abs_Coef'][-numtop:], color=colors)

plt.ylabel('Feature')
plt.xlabel('Magnitude of Coefficient')
plt.title('Top ' + str(numtop) + ' Features')

legend_labels = [Patch(color='blue', label='+ Correlation'),
                 Patch(color='orange', label='- Correlation')]
plt.legend(handles=legend_labels)

plt.show()

# %%
indices = np.argsort(np.abs(coefficients))[-30:]

plt.figure(figsize=(10, 6))
plt.title('Top Features')
plt.barh(range(len(indices)), coefficients[indices], color='b', align='center')
plt.yticks(range(len(indices)), [features[i] for i in indices])
plt.xlabel('Coefficient Value')
plt.show()

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
cm
# Out:
# array([[164,   5],
#        [ 10,  70]])

# %%
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'])
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

# %%
#Separate out the prediction column. Remove the text column (can't standardize text) as well as the coded emotions.
X_train_without_clusters  = X_train.drop(columns=[x for x in X_train.columns if 'cluster_by_hierarcal_5' in x] + [x for x in X_train.columns if 'kmeans_wlang_elbow' in x]+ [x for x in X_train.columns if 'kmeans_wolang_elbow_' in x])
X_test_without_clusters  = X_test.drop(columns=[x for x in X_test.columns if 'cluster_by_hierarcal_5' in x] + [x for x in X_test.columns if 'kmeans_wlang_elbow' in x]+ [x for x in X_test.columns if 'kmeans_wolang_elbow_' in x])

# %% [markdown]
# Logistic Regression

# %%
#use same scorer and modeling stuff as above, just new data
grid_search.fit(X_train, y_train)
print("Best parameters:", grid_search.best_params_)
print("Best cross-validation score: {:.2f}".format(grid_search.best_score_))
best_model_without_clusters = grid_search.best_estimator_
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END ..........C=0.01, solver=liblinear;, score=0.933 total time=   0.2s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ..........C=0.01, solver=liblinear;, score=0.929 total time=   0.1s
# [CV 3/5] END ..........C=0.01, solver=liblinear;, score=0.941 total time=   0.1s
# [CV 4/5] END ..........C=0.01, solver=liblinear;, score=0.930 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ..........C=0.01, solver=liblinear;, score=0.921 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ...............C=0.01, solver=saga;, score=0.928 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ...............C=0.01, solver=saga;, score=0.926 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ...............C=0.01, solver=saga;, score=0.936 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...............C=0.01, solver=saga;, score=0.928 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ...............C=0.01, solver=saga;, score=0.916 total time=   0.8s
# [CV 1/5] END ...........C=0.1, solver=liblinear;, score=0.966 total time=   0.1s
# [CV 2/5] END ...........C=0.1, solver=liblinear;, score=0.976 total time=   0.1s
# [CV 3/5] END ...........C=0.1, solver=liblinear;, score=0.977 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...........C=0.1, solver=liblinear;, score=0.966 total time=   0.1s
# [CV 5/5] END ...........C=0.1, solver=liblinear;, score=0.957 total time=   0.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ................C=0.1, solver=saga;, score=0.961 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ................C=0.1, solver=saga;, score=0.969 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ................C=0.1, solver=saga;, score=0.974 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ................C=0.1, solver=saga;, score=0.958 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ................C=0.1, solver=saga;, score=0.950 total time=   0.8s
# [CV 1/5] END .............C=1, solver=liblinear;, score=0.941 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .............C=1, solver=liblinear;, score=0.964 total time=   0.5s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .............C=1, solver=liblinear;, score=0.955 total time=   0.7s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END .............C=1, solver=liblinear;, score=0.923 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END .............C=1, solver=liblinear;, score=0.936 total time=   0.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ..................C=1, solver=saga;, score=0.925 total time=   1.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ..................C=1, solver=saga;, score=0.964 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ..................C=1, solver=saga;, score=0.969 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ..................C=1, solver=saga;, score=0.950 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ..................C=1, solver=saga;, score=0.945 total time=   0.9s
# [CV 1/5] END ............C=10, solver=liblinear;, score=0.886 total time=   1.5s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ............C=10, solver=liblinear;, score=0.925 total time=   1.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ............C=10, solver=liblinear;, score=0.925 total time=   2.1s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ............C=10, solver=liblinear;, score=0.909 total time=   1.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ............C=10, solver=liblinear;, score=0.923 total time=   1.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END .................C=10, solver=saga;, score=0.922 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END .................C=10, solver=saga;, score=0.963 total time=   0.9s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END .................C=10, solver=saga;, score=0.967 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END .................C=10, solver=saga;, score=0.943 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END .................C=10, solver=saga;, score=0.942 total time=   0.8s
# [CV 1/5] END ...........C=100, solver=liblinear;, score=0.883 total time=   1.5s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ...........C=100, solver=liblinear;, score=0.910 total time=   1.4s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ...........C=100, solver=liblinear;, score=0.922 total time=   1.6s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ...........C=100, solver=liblinear;, score=0.904 total time=   1.2s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 5/5] END ...........C=100, solver=liblinear;, score=0.908 total time=   1.5s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 1/5] END ................C=100, solver=saga;, score=0.921 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 2/5] END ................C=100, solver=saga;, score=0.962 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 3/5] END ................C=100, solver=saga;, score=0.967 total time=   0.8s
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [CV 4/5] END ................C=100, solver=saga;, score=0.942 total time=   0.7s
# [CV 5/5] END ................C=100, solver=saga;, score=0.942 total time=   0.8s
# Best parameters: {'C': 0.1, 'solver': 'liblinear'}
# Best cross-validation score: 0.97
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/linear_model/_sag.py:350: ConvergenceWarning: The max_iter was reached which means the coef_ did not converge
#   warnings.warn(
# /Users/danny/Library/Python/3.9/lib/python/site-packages/sklearn/utils/validation.py:1300: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
# Predict test data
y_pred_wc = best_model_without_clusters.predict(X_test)

# Evaluate the model
print("Test Accuracy:", accuracy_score(y_test, y_pred_wc))
print("Classification Report:\n", classification_report(y_test, y_pred_wc))
print("Confusion Matrix:\n", confusion_matrix(y_test, y_pred_wc))
# Out:
# Test Accuracy: 0.9397590361445783
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.94      0.97      0.96       169
#            1       0.93      0.88      0.90        80
#
#     accuracy                           0.94       249
#    macro avg       0.94      0.92      0.93       249
# weighted avg       0.94      0.94      0.94       249
#
# Confusion Matrix:
#  [[164   5]
#  [ 10  70]]

# %%
y_pred_prob_wc = best_model_without_clusters.predict_proba(X_test)

# %%
#Make ROC Curve
fpr_wc, tpr_wc, thresholds_wc = roc_curve(y_test, y_pred_prob_wc[:, 1])

plt.figure(figsize=(8, 6))
plt.plot(fpr_wc, tpr_wc, label=f'ROC curve (area = {roc_auc_score(y_test, y_pred_prob_wc[:, 1]):.2f})')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc='best')
plt.show()

# %%
#Find features with non-0 betas

#get full list of features and their coefficients
features_wc = X_test.columns
coefficients_wc = best_model_without_clusters.coef_.flatten()
fulllist_wc= pd.DataFrame(np.transpose([features_wc, coefficients_wc]))
#remove rows with 0 as a coefficient
shortlist_wc = fulllist_wc[fulllist_wc[1] != 0]
#show how many features were not kicked out of the model:
print(len(shortlist_wc))
# Out:
# 105

# %%
#sort and plot the coefficients
coef_sorted_wc = shortlist_wc.reindex(shortlist_wc[1].abs().sort_values(ascending=False).index)
coef_sorted_wc['Abs_Coef'] = coef_sorted_wc[1].abs()

#look at all of them to get their distribution
colors = ['blue' if val >= 0 else 'orange' for val in coef_sorted_wc[1]]
plt.bar(range(len(coef_sorted_wc[0])), coef_sorted_wc['Abs_Coef'], color=colors)
#plt.bar(coef_sorted[0], coef_sorted['Abs_Coef'], color=colors)
plt.xlabel('# Features')
plt.ylabel('Magnitude of Coefficient')
plt.title('Coefficients for All Features')

legend_labels = [Patch(color='blue', label='+ Correlation'),
                 Patch(color='orange', label='- Correlation')]
plt.legend(handles=legend_labels)

plt.show()

# %%
#look at just the top few of them to get their distribution
numtop = 18

#reverses the order
coef_sorted_wc = coef_sorted_wc.iloc[::-1]

colors = ['blue' if val >= 0 else 'orange' for val in coef_sorted_wc[1]]
plt.barh(coef_sorted_wc[0][-numtop:], coef_sorted_wc['Abs_Coef'][-numtop:], color=colors)

plt.ylabel('Feature')
plt.xlabel('Magnitude of Coefficient')
plt.title('Top ' + str(numtop) + ' Features')

legend_labels = [Patch(color='blue', label='+ Correlation'),
                 Patch(color='orange', label='- Correlation')]
plt.legend(handles=legend_labels)

plt.show()

# %%
indices_wc = np.argsort(np.abs(coefficients_wc))[-30:]

plt.figure(figsize=(10, 6))
plt.title('Top Features')
plt.barh(range(len(indices_wc)), coefficients_wc[indices_wc], color='b', align='center')
plt.yticks(range(len(indices_wc)), [features_wc[i] for i in indices_wc])
plt.xlabel('Coefficient Value')
plt.show()

# %%
# Confusion Matrix
cm_wc = confusion_matrix(y_test, y_pred_wc)

plt.figure(figsize=(6, 4))
sns.heatmap(cm_wc, cmap='Blues', xticklabels=['Predicted 0', 'Predicted 1'], yticklabels=['Actual 0', 'Actual 1'], annot=True, fmt='d', annot_kws={"size": 16})
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()
